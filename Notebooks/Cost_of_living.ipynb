# %% [markdown]
# # Cost of living

# %%
import pandas as pd

# %%
df = pd.read_csv('wikipedia_cost_of_living_indices3.csv')

# %%
df
# Out:
#          Country  Cost of Living Index  Rent Index  \
# 0    Switzerland                 101.1        46.5
# 1        Bahamas                  85.0        36.7
# 2        Iceland                  83.0        39.2
# 3      Singapore                  76.7        67.2
# 4       Barbados                  76.6        19.0
# ..           ...                   ...         ...
# 116   Bangladesh                  22.5         2.4
# 117        India                  21.2         5.6
# 118        Egypt                  21.0         3.7
# 119        Libya                  20.4         4.3
# 120     Pakistan                  18.8         2.8
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                              74.9            109.1                    97.0
# 1                              61.8             81.6                    83.3
# 2                              62.0             88.4                    86.8
# ...

# %%
countries = [
    'Portugal', 'Estonia', 'Georgia', 'Spain', 'United States', 
    'Thailand', 'Serbia', 'Vietnam', 'Philippines', 'Mexico', 
    'Colombia', 'Uruguay', 'Argentina'
]

# %%
cost_living_df = df[df['Country'].isin(countries)]
#cost_living

# %%
cost_living_df = cost_living.sort_values('Country', ascending=True)
cost_living_df = cost_living.reset_index(drop=True)

# %%
cost_living_df = pd.DataFrame(cost_living_df)
cost_living_df
# Out:
#           Country  Cost of Living Index  Rent Index  \
# 0       Argentina                  29.4         7.6
# 1        Colombia                  28.8         8.6
# 2         Estonia                  52.0        15.0
# 3         Georgia                  33.4        13.7
# 4          Mexico                  40.2        15.5
# 5     Philippines                  31.0         7.1
# 6        Portugal                  45.1        24.0
# 7          Serbia                  37.7        12.4
# 8           Spain                  47.3        22.9
# 9        Thailand                  34.1        11.2
# 10  United States                  70.4        41.7
# 11        Uruguay                  54.1        13.8
# 12        Vietnam                  28.7         9.0
#
#     Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                             18.9             29.7                    24.8
# 1                             19.1             30.3                    20.5
# ...

# %%
cost_living_df.to_csv('cost_of_living_countries_clean.csv', index=False)

# %% [markdown]
# # Cost of Living Cities

# %%
regional_cost_df = pd.read_csv('movehubqualityoflife.csv')

# %%
regional_cost_df.head()
# Out:
#            City  Movehub Rating  Purchase Power  Health Care  Pollution  \
# 0       Caracas           65.18           11.25        44.44      83.45
# 1  Johannesburg           84.08           53.99        59.98      47.39
# 2     Fortaleza           80.17           52.28        45.46      66.32
# 3   Saint Louis           85.25           80.40        77.29      31.33
# 4   Mexico City           75.07           24.28        61.76      18.95
#
#    Quality of Life  Crime Rating
# 0             8.61         85.70
# 1            51.26         83.93
# 2            36.68         78.65
# 3            87.51         78.13
# 4            27.91         77.86

# %%
cities = [
   'Lisbon',
    'Tallinn',
    'Tbilisi',
    'Madrid',
    'New York City',
    'Bangkok',
    'Belgrade',  
    'Hanoi',
    'Manila',
    'Mexico City',
    'Bogotá',
    'Montevideo',
    'Buenos Aires'
]

# %%
regional_cost_clean_df = regional_cost_df[regional_cost_df['City'].isin(cities)]
regional_cost_clean_df = regional_cost_clean_df.reset_index(drop=True)

# %%
regional_cost_clean_df
# Out:
#            City  Movehub Rating  Purchase Power  Health Care  Pollution  \
# 0   Mexico City           75.07           24.28        61.76      18.95
# 1        Manila           68.31           14.80        80.56      65.22
# 2  Buenos Aires           77.29           29.29        79.17      47.26
# 3         Hanoi           66.77           12.22        20.83      24.02
# 4    Montevideo           71.69           21.56        59.72      31.72
# 5        Lisbon           77.63           32.48        62.38      28.78
# 6        Madrid           85.37           54.07        73.51      55.77
# 7      Belgrade           71.65           21.46        52.53      77.08
# 8       Bangkok           74.21           20.82        95.96      60.39
#
#    Quality of Life  Crime Rating
# 0            27.91         77.86
# 1            13.14         66.36
# 2            39.78         59.46
# 3             5.29         51.81
# 4            44.63         50.16
# 5            56.08         40.08
# ...

# %% [markdown]
# Movehub Rating: A combination of all scores for an overall rating for a city or country.
# Purchase Power: This compares the average cost of living with the average local wage.
# Health Care: Compiled from how citizens feel about their access to healthcare, and its quality.
# Pollution: Low is good. A score of how polluted people find a city, includes air, water and noise pollution.
# Quality of Life: A balance of healthcare, pollution, purchase power, crime rate to give an overall quality of life score.
# Crime Rating: Low is good. The lower the score the safer people feel in this city.

# %%
city_to_country = {
    'Mexico City': 'Mexico',
    'Manila': 'Philippines',
    'Buenos Aires': 'Argentina',
    'Hanoi': 'Vietnam',
    'Montevideo': 'Uruguay',
    'Lisbon': 'Portugal',
    'Madrid': 'Spain',
    'Belgrade': 'Serbia',
    'Bangkok': 'Thailand'
}

# %%
regional_cost_clean_df['Country'] = regional_cost_clean_df['City'].map(city_to_country)
# Move the 'Country' column to the first position
regional_cost_clean_df = regional_cost_clean_df[['Country'] + [col for col in regional_cost_clean_df.columns if col != 'Country']]

# %%
regional_cost_clean_df
# Out:
#        Country          City  Movehub Rating  Purchase Power  Health Care  \
# 0       Mexico   Mexico City           75.07           24.28        61.76
# 1  Philippines        Manila           68.31           14.80        80.56
# 2    Argentina  Buenos Aires           77.29           29.29        79.17
# 3      Vietnam         Hanoi           66.77           12.22        20.83
# 4      Uruguay    Montevideo           71.69           21.56        59.72
# 5     Portugal        Lisbon           77.63           32.48        62.38
# 6        Spain        Madrid           85.37           54.07        73.51
# 7       Serbia      Belgrade           71.65           21.46        52.53
# 8     Thailand       Bangkok           74.21           20.82        95.96
#
#    Pollution  Quality of Life  Crime Rating
# 0      18.95            27.91         77.86
# 1      65.22            13.14         66.36
# 2      47.26            39.78         59.46
# 3      24.02             5.29         51.81
# ...

# %%
regional_cost_clean_df = regional_cost_clean_df.reset_index(drop=True)
regional_cost_clean_df = regional_cost_clean_df.sort_values('Country', ascending=True)

# %%
regional_cost_clean_df
# Out:
#        Country          City  Movehub Rating  Purchase Power  Health Care  \
# 0    Argentina  Buenos Aires           77.29           29.29        79.17
# 1       Mexico   Mexico City           75.07           24.28        61.76
# 2  Philippines        Manila           68.31           14.80        80.56
# 3     Portugal        Lisbon           77.63           32.48        62.38
# 4       Serbia      Belgrade           71.65           21.46        52.53
# 5        Spain        Madrid           85.37           54.07        73.51
# 6     Thailand       Bangkok           74.21           20.82        95.96
# 7      Uruguay    Montevideo           71.69           21.56        59.72
# 8      Vietnam         Hanoi           66.77           12.22        20.83
#
#    Pollution  Quality of Life  Crime Rating
# 0      47.26            39.78         59.46
# 1      18.95            27.91         77.86
# 2      65.22            13.14         66.36
# 3      28.78            56.08         40.08
# ...

# %%
regional_cost_clean_df.to_csv('cost_of_living_cities_clean.csv', index=False)

# %% [markdown]
# # Global income purchase power

# %%
global_income_df = pd.read_csv('worldwide.csv')
global_income_df
# Out:
#      Rank              Country/Region  Cost index Ø Monthly income  \
# 0       1                   Bermuda *       157.9       10,437 USD
# 1       2            Cayman Islands *       138.3        5,433 USD
# 2       3                 Switzerland       131.4        7,454 USD
# 3       4  Turks and Caicos Islands *       124.6        2,013 USD
# 4       5                      Israel       123.1        4,554 USD
# ..    ...                         ...         ...              ...
# 96     97                  Tajikistan        23.5          101 USD
# 97     98                    Pakistan        23.1          132 USD
# 98     99                     Myanmar        22.7          101 USD
# 99    100                  Uzbekistan        21.7          183 USD
# 100   101                   Palestine        17.7          384 USD
#
#      Purchasing power index
# 0                     103.8
# 1                      61.7
# 2                      89.1
# 3                      25.4
# ...

# %%
global_income_df = global_income_df.rename(columns={'Country/Region': 'Country'})

# %%
countries = [
    'Portugal', 'Estonia', 'Georgia', 'Spain', 'United States', 
    'Thailand', 'Serbia', 'Vietnam', 'Philippines', 'Mexico', 
    'Colombia', 'Uruguay', 'Argentina'
]

# %%
global_income_clean_df = global_income_df[global_income_df['Country'].isin(countries)]

# %%
global_income_clean_df = global_income_clean_df.sort_values('Country', ascending=True)
global_income_clean_df = global_income_clean_df.reset_index(drop=True)
global_income_clean_df = global_income_clean_df.drop(columns=['Rank'])

# %%
global_income_clean_df
# Out:
#          Country  Cost index Ø Monthly income  Purchasing power index
# 0       Colombia        38.2          543 USD                    22.3
# 1        Georgia        36.7          468 USD                    20.0
# 2         Mexico        58.5          868 USD                    23.3
# 3    Philippines        36.5          329 USD                    14.2
# 4       Portugal        67.9        2,150 USD                    49.7
# 5         Serbia        47.4          762 USD                    25.2
# 6          Spain        73.0        2,640 USD                    56.9
# 7       Thailand        34.7          603 USD                    27.3
# 8  United States       100.0        6,364 USD                   100.0
# 9        Vietnam        32.4          334 USD                    16.2

# %%
global_income_clean_df.to_csv('global_income_clean.csv', index=False)
