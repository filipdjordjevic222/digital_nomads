# 10  United States  New York City   0.6   2.1   6.1  11.9  17.1  22.1  24.9
# 11        Uruguay     Montevideo  23.0  22.5  20.6  17.2  14.0  11.1  10.9
# 12        Vietnam          Hanoi  16.4  17.2  20.0  23.9  27.4  28.9  29.2
#
#      Aug   Sep   Oct   Nov   Dec
# 0   12.8  14.6  17.9  20.7  23.3
# 1   14.1  14.3  14.3  14.4  14.6
# 2   16.5  12.0   6.5   2.0  -0.9
# 3   24.1  19.6  13.7   7.8   3.2
# 4   18.3  18.0  17.1  16.3  15.0
# 5   28.3  28.4  28.4  28.0  27.0
# 6   23.5  22.1  18.8  15.0  12.4
# 7   22.7  18.0  12.9   7.1   2.7
# 8   25.1  20.9  15.1   9.9   6.9
# 9   28.8  28.3  28.1  27.8  26.5
# 10  24.3  20.2  14.1   8.9   3.3
# 11  11.7  13.4  16.0  18.6  21.3
# 12  28.6  27.5  24.9  21.5  18.2

# %% [markdown]
# # Heatmap

# %%
weather_df_heatmap = weather_df.set_index(['Country', 'City'])[months]

# Plot heatmap
plt.figure(figsize=(14, 8))
sns.heatmap(weather_df_heatmap.T, annot=True, cmap='coolwarm', fmt=".1f", linewidths=0.5)
plt.title('Average Monthly Temperature by Country and City')
plt.xlabel('Country and City')
plt.ylabel('Month')
plt.xticks(rotation=90)
plt.tight_layout()

#save 
plt.savefig('weather_heathmap.png', bbox_inches='tight', dpi=80)
plt.show()

# %% [markdown]
# # Boxplot temperature distribution

# %%
weather_df_long = pd.melt(weather_df, id_vars=['Country', 'City'], value_vars=months, var_name='Month', value_name='Temperature')


plt.figure(figsize=(14, 6))
sns.boxplot(x='Country', y='Temperature', data=weather_df_long)
plt.title('Temperature Distribution by Country')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Temperature (°C)')
plt.tight_layout()

#save
plt.savefig('Temperature_distribution.png', bbox_inches='tight', dpi=100)
plt.show()

# %% [markdown]
# # Average temperature by Country

# %%
# Calculate average temperature across all months for each country
weather_df['Avg_Temperature'] = weather_df[months].mean(axis=1)


plt.figure(figsize=(14, 6))
sns.barplot(x='Country', y='Avg_Temperature', data=weather_df)
plt.title('Average Temperature by Country')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Average Temperature (°C)')
plt.tight_layout()

#save
plt.savefig('Average_Temperatur.png', bbox_inches='tight', dpi=100)
plt.show()

# %% [markdown]
# # Monthly temperature by Cities

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Melt the dataframe to make it long format for easy plotting
weather_df_long = pd.melt(weather_df, id_vars=['Country', 'City'], value_vars=months,
                          var_name='Month', value_name='Temperature')


plt.figure(figsize=(14, 8))


sns.lineplot(x='Month', y='Temperature', data=weather_df_long, hue='City', marker='o', palette='tab20')


plt.title('Monthly Temperature Fluctuations for Each City Throughout the Year')
plt.xlabel('Month')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.legend(title='City', bbox_to_anchor=(1.05, 1), loc='upper left')

# save
plt.tight_layout()
plt.savefig('monthly_temperature_cities.png', bbox_inches='tight', dpi=100)
plt.show()
