# %% [markdown]
# # Weather

# %%
import pandas as pd

# %%
weather_df = pd.read_csv('worlds_all_cities_with_their_avg_temp-Sheet1.csv')

# %%
weather_df.head()
# Out:
#    Country         City           Jan           Feb           Mar  \
# 0  Algeria      Algiers  11.2\n(52.2)  11.9\n(53.4)  12.8\n(55.0)
# 1  Algeria  Tamanrasset  12.8\n(55.0)  15.0\n(59.0)  18.1\n(64.6)
# 2  Algeria      Reggane  16.0\n(60.8)  18.2\n(64.8)  23.1\n(73.6)
# 3   Angola       Luanda  26.7\n(80.1)  28.5\n(83.3)  28.6\n(83.5)
# 4    Benin      Cotonou  27.3\n(81.1)  28.5\n(83.3)  28.9\n(84.0)
#
#             Apr           May           Jun            Jul            Aug  \
# 0  14.7\n(58.5)  17.7\n(63.9)  21.3\n(70.3)   24.6\n(76.3)   25.2\n(77.4)
# 1  22.2\n(72.0)  26.1\n(79.0)  28.9\n(84.0)   28.7\n(83.7)   28.2\n(82.8)
# 2  27.9\n(82.2)  32.2\n(90.0)  36.4\n(97.5)  39.8\n(103.6)  38.4\n(101.1)
# 3  28.2\n(82.8)  27.0\n(80.6)  23.9\n(75.0)   22.1\n(71.8)   22.1\n(71.8)
# 4  28.6\n(83.5)  27.8\n(82.0)  26.5\n(79.7)   25.8\n(78.4)   25.6\n(78.1)
#
#             Sep           Oct           Nov           Dec          Year Ref.
# ...

# %%
weather_df.columns
# Out:
# Index(['Country', 'City', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul',
#        'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Year', 'Ref.'],
#       dtype='object')

# %%
weather_df.dtypes
# Out:
# Country    object
# City       object
# Jan        object
# Feb        object
# Mar        object
# Apr        object
# May        object
# Jun        object
# Jul        object
# Aug        object
# Sep        object
# Oct        object
# Nov        object
# Dec        object
# Year       object
# Ref.       object
# dtype: object

# %%
countries_and_capitals = {
    'Portugal': 'Lisbon',
    'Estonia': 'Tallinn',
    'Georgia': 'Tbilisi',
    'Spain': 'Madrid',
    'United States':'New York City',
    'Thailand': 'Bangkok',
    'Serbia': 'Belgrade',  
    'Vietnam': 'Hanoi',
    'Philippines': 'Manila',
    'Mexico': 'Mexico City',
    'Colombia': 'Bogotá',
    'Uruguay': 'Montevideo',
    'Argentina': 'Buenos Aires'
}

# %%
weather_countries_df = weather_df[weather_df['Country'].isin(countries_and_capitals.keys()) & 
                 weather_df['City'].isin(countries_and_capitals.values())]

# %%
weather_countries_df.head()
# Out:
#          Country     City           Jan           Feb           Mar  \
# 132      Georgia  Tbilisi   1.2\n(34.2)   2.7\n(36.9)   6.6\n(43.9)
# 176  Philippines   Manila  26.7\n(80.1)  27.4\n(81.3)  28.7\n(83.7)
# 192     Thailand  Bangkok  27.0\n(80.6)  28.3\n(82.9)  29.5\n(85.1)
# 204      Vietnam    Hanoi  16.4\n(61.5)  17.2\n(63.0)  20.0\n(68.0)
# 220      Estonia  Tallinn  −2.9\n(26.8)  −3.6\n(25.5)  −0.6\n(30.9)
#
#               Apr           May           Jun           Jul           Aug  \
# 132  12.2\n(54.0)  17.4\n(63.3)  21.3\n(70.3)  24.5\n(76.1)  24.1\n(75.4)
# 176  30.1\n(86.2)  30.0\n(86.0)  29.3\n(84.7)  28.5\n(83.3)  28.3\n(82.9)
# 192  30.5\n(86.9)  29.9\n(85.8)  29.5\n(85.1)  29.0\n(84.2)  28.8\n(83.8)
# 204  23.9\n(75.0)  27.4\n(81.3)  28.9\n(84.0)  29.2\n(84.6)  28.6\n(83.5)
# 220   4.8\n(40.6)  10.2\n(50.4)  14.5\n(58.1)  17.6\n(63.7)  16.5\n(61.7)
#
#               Sep           Oct           Nov           Dec          Year  \
# ...

# %%
#weather_countries_df.dtypes

# %%
#reset index and drop ref.column
weather_countries_df = weather_countries_df.drop(columns=['Ref.'])
weather_countries_df= weather_countries_df.reset_index(drop=True)

# %%
#Just in Celsius temperature
def extract_celsius(temp_str):
   
    temp_str = temp_str.split('\n')[0]  # Get the part before the newline
    temp_str = temp_str.replace('−', '-')  # Replace the special minus sign with the standard one
    temp_str = temp_str.strip()  # Remove any leading/trailing whitespace
    try:
        return float(temp_str)  # Convert to float
    except ValueError:
        return None

# %%
temperature_columns = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Year']
for col in temperature_columns:
    weather_countries_df[col] = weather_countries_df[col].apply(extract_celsius)

# %%
#weather_countries_df

# %%
weather_countries_df = weather_countries_df.sort_values("Country", ascending=True)
weather_countries_df = weather_countries_df.reset_index(drop=True)

# %%
weather_countries_df
# Out:
#           Country           City   Jan   Feb   Mar   Apr   May   Jun   Jul  \
# 0       Argentina   Buenos Aires  24.9  23.6  21.9  17.9  14.5  11.7  11.0
# 1        Colombia         Bogotá  14.3  14.5  14.9  14.9  15.0  14.5  14.6
# 2         Estonia        Tallinn  -2.9  -3.6  -0.6   4.8  10.2  14.5  17.6
# 3         Georgia        Tbilisi   1.2   2.7   6.6  12.2  17.4  21.3  24.5
# 4          Mexico    Mexico City  14.6  15.9  18.1  19.6  20.0  19.4  18.2
# 5     Philippines         Manila  26.7  27.4  28.7  30.1  30.0  29.3  28.5
# 6        Portugal         Lisbon  11.6  12.7  14.9  15.9  18.0  21.2  23.1
# 7          Serbia       Belgrade   1.4   3.1   7.6  12.9  18.1  21.0  23.0
# 8           Spain         Madrid   6.3   7.9  11.2  12.9  16.7  22.2  25.6
# 9        Thailand        Bangkok  27.0  28.3  29.5  30.5  29.9  29.5  29.0
# 10  United States  New York City   0.6   2.1   6.1  11.9  17.1  22.1  24.9
# ...

# %%
weather_countries_df.to_csv('weather_countries_clean.csv', index=False)
